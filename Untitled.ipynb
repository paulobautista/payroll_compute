# %%
import pandas as pd

# %%
import itertools

# %%
df = pd.read_csv('sample_route_data.csv')

# %%
ps = pd.read_csv('sample_payscheme.csv')

# %%
def get_scheme_rate(row):
    hub = ps.hub_id == row.hub_id
    driver_type = ps.driver_type ==row.driver_type
    min_parcel = ps.min_parcel < row.parcels_delivered 
    rate_card =  tuple(ps.loc[hub & driver_type & min_parcel].agg({'per_parcel_rate':'max','daily_min_wage':'max','fixed_component':'max','fixed_incentive_component':'max'}).fillna(0))
    revenue = (rate_card[0] * row.parcels_delivered) + (sum(rate_card[1:]))
    return revenue,rate_card

# %%
df['result'] = df.apply(get_scheme_rate,axis=1)
df['delivery_pay']  = [x[0] for x in df.result]

# %%
df.groupby(['rider_id','rider_name','hub_id','hub_name','driver_type']).agg({'parcels_delivered':'sum','route_date':'nunique','delivery_pay':'sum'}).reset_index().to_csv('rider_level.csv',index=False)
# Out:
#     rider_id                  rider_name  hub_id      hub_name  \
# 0    1001333                 M6 - Dennis       1  MAKATI 1-TGG
# 1    1001802            M6 - MarkAnthony       1  MAKATI 1-TGG
# 2    1002066                  M6 - Sandy       1  MAKATI 1-TGG
# 3    1010738                 M6 - Nestor       1  MAKATI 1-TGG
# 4    1026380                 M6 - Joemel       1  MAKATI 1-TGG
# 5    1040392         M6 - Kenneth Alfred       1  MAKATI 1-TGG
# 6    1040748                   M6 - Eric       1  MAKATI 1-TGG
# 7    1051419                M10 - Eugine       1  MAKATI 1-TGG
# 8    1059384           M6 - Luis Anthony       1  MAKATI 1-TGG
# 9    1059404               M6 - Angelito       1  MAKATI 1-TGG
# 10   1061824            M6 - CarlSherwin       1  MAKATI 1-TGG
# 11   1063918           M6 - Michael John       1  MAKATI 1-TGG
# 12   1063988                M6 - Lambert       1  MAKATI 1-TGG
# 13   1064286            M13- Ervin Jason       1  MAKATI 1-TGG
# 14   1064288                M13- Clayson       1  MAKATI 1-TGG
# 15   1067409          M6 - ChristianKyle       1  MAKATI 1-TGG
# 16   1067412              M6 - Alexander       1  MAKATI 1-TGG
# 17   1067736           M6 - MariaJuvella       1  MAKATI 1-TGG
# 18   1075555             M9 - John David       1  MAKATI 1-TGG
# 19   1077835       G5 - Joseph BobbyLito       1  MAKATI 1-TGG
# 20   1082416             M13- Armando Go       1  MAKATI 1-TGG
# 21   1083334          M10 - Jefferson G.       1  MAKATI 1-TGG
# 22   1090240                 M13- WILMAR       1  MAKATI 1-TGG
# 23   1091317              M10 - Michelle       1  MAKATI 1-TGG
# 24   1094759           M6 - Patrick Efgh       1  MAKATI 1-TGG
# 25   1111856            M10 - Don Gerald       1  MAKATI 1-TGG
# 26   1117490             M6 - John Brian       1  MAKATI 1-TGG
# 27   1121267                M10 - Jhason       1  MAKATI 1-TGG
# 28   1128182          M6 - Francis Emiko       1  MAKATI 1-TGG
# 29   1130063                 M6 - Eduard       1  MAKATI 1-TGG
# 30   1131515                M6 - Alfredo       1  MAKATI 1-TGG
# 31   1137820                 M6 - Marvin       1  MAKATI 1-TGG
# 32   1138792            M6 - Ronald Yuji       1  MAKATI 1-TGG
# 33   1145419                    M9 - Jay       1  MAKATI 1-TGG
# 34   1145437               M9 - Santiago       1  MAKATI 1-TGG
# 35   1145932              M10 - Daryl V.       1  MAKATI 1-TGG
# 36   1146538                M6 - Anthony       1  MAKATI 1-TGG
# 37   1147596                 M6 - Joemar       1  MAKATI 1-TGG
# 38   1156865            M6-Thomas Jester       1  MAKATI 1-TGG
# 39   1161875                   M6-Harvee       1  MAKATI 1-TGG
# 40   1162343                   M6-Marvin       1  MAKATI 1-TGG
# 41   1176618           M10 - Rio Jhon P.       1  MAKATI 1-TGG
# 42   1180675               M6 - Credence       1  MAKATI 1-TGG
# 43   1182687  M6 - Seasonal John Kenneth       1  MAKATI 1-TGG
# 44   1182857                M6 - Raphael       1  MAKATI 1-TGG
# 45   1185503               M6-Van Jarvis       1  MAKATI 1-TGG
# 46   1186757                   M6-Edward       1  MAKATI 1-TGG
# 47   1190183                  C34-Junrey       1  MAKATI 1-TGG
# 48   1196847                  M6 - Harry       1  MAKATI 1-TGG
# 49   1198173                F8-Jan Robby       1  MAKATI 1-TGG
# 50   1199079        M6 - Seasonal August       1  MAKATI 1-TGG
# 51   1202221  M6 - Seasonal Bren Michael       1  MAKATI 1-TGG
# 52   1211755           A14 - Demosthenes       1  MAKATI 1-TGG
#
#                 driver_type  parcels_delivered  route_date  delivery_pay
# 0   Rider - Per Parcel Rate                160           7        6434.0
# 1   Rider - Per Parcel Rate                313          15       13081.0
# 2   Rider - Per Parcel Rate                406          14       13658.0
# 3   Rider - Per Parcel Rate                 12           1         797.0
# 4   Rider - Per Parcel Rate                 35           2        1649.0
# 5   Rider - Per Parcel Rate                299          11       10479.0
# 6   Rider - Per Parcel Rate                318          11       10981.0
# 7   Rider - Per Parcel Rate                 30           2        1597.0
# 8   Rider - Per Parcel Rate                  7           1         751.0
# 9   Rider - Per Parcel Rate                118           8        6402.0
# 10  Rider - Per Parcel Rate                 10           1         757.0
# 11  Rider - Per Parcel Rate                 24           2        1561.0
# 12  Rider - Per Parcel Rate                 10           1         757.0
# 13  Rider - Per Parcel Rate                 39           1        1127.0
# 14  Rider - Per Parcel Rate                 43           1        1167.0
# 15  Rider - Per Parcel Rate                 38           1        1117.0
# 16  Rider - Per Parcel Rate                 72           6        4740.0
# 17  Rider - Per Parcel Rate                181           9        7856.0
# 18  Rider - Per Parcel Rate                 23           1         852.0
# 19                   Sacked                  2           2           0.0
# 20  Rider - Per Parcel Rate                 46           2        1704.0
# 21  Rider - Per Parcel Rate                 24           2        1561.0
# 22  Rider - Per Parcel Rate                 17           1         822.0
# 23  Rider - Per Parcel Rate                 20           1         837.0
# 24  Rider - Per Parcel Rate                 14           1         807.0
# 25  Rider - Per Parcel Rate                 36           2        1654.0
# 26  Rider - Per Parcel Rate                  7           1         751.0
# 27  Rider - Per Parcel Rate                 35           2        1649.0
# 28  Rider - Per Parcel Rate                206           8        7640.0
# 29  Rider - Per Parcel Rate                 28           1         877.0
# 30  Rider - Per Parcel Rate                146           7        6370.0
# 31  Rider - Per Parcel Rate                122           6        5360.0
# 32  Rider - Per Parcel Rate                 24           1         857.0
# 33  Rider - Per Parcel Rate                 73           2        2089.0
# 34  Rider - Per Parcel Rate                 45           2        1854.0
# 35  Rider - Per Parcel Rate                 28           2        1614.0
# 36  Rider - Per Parcel Rate                 25           2        1572.0
# 37  Rider - Per Parcel Rate                  8           1         753.0
# 38  Rider - Per Parcel Rate                189          11        9133.0
# 39  Rider - Per Parcel Rate                 25           3        2261.0
# 40  Rider - Per Parcel Rate                236          10        9217.0
# 41  Rider - Per Parcel Rate                 17           1         822.0
# 42  Rider - Per Parcel Rate                108           8        6367.0
# 43  Rider - Per Parcel Rate                 39           4        3125.0
# 44  Rider - Per Parcel Rate                 21           2        1564.0
# 45  Rider - Per Parcel Rate                 26           2        1604.0
# 46  Rider - Per Parcel Rate                177           9        7704.0
# 47         Rider - Seasonal                 14           1           0.0
# 48  Rider - Per Parcel Rate                 39           2        1669.0
# 49         Rider - Seasonal                  6           1           0.0
# 50  Rider - Per Parcel Rate                107           7        5793.0
# 51  Rider - Per Parcel Rate                129           8        6526.0
# 52         Rider - Seasonal                  0           2           0.0
